# %% [markdown]
# # Imports and setup

# %%
import psycopg2
import numpy as np
import pandas as pd
import os
import datetime
import csv
import glob
import time

from mysecrets import username, password, hostname, port

# %%
HOME_PATH = os.getcwd()
print(HOME_PATH)
# pd.read_csv
# Out:
# /home/denny/Documents/mids/ev_charging

# %%
conn = psycopg2.connect(
    host=hostname,
    database="postgres",
    user=username,
    password=password)
conn
# Out:
# <connection object at 0x7f092de13740; dsn: 'user=postgres password=xxx dbname=postgres host=evdb.cjcyce60qgvj.us-east-1.rds.amazonaws.com', closed: 0>

# %%
def get_connection():
    return psycopg2.connect(
    host=hostname,
    database="postgres",
    user=username,
    password=password)

# %%
def run_query(query):
    conn = get_connection()
    with conn.cursor() as cur:
        cur.execute(query)
        try:
            results = cur.fetchall()
        except:
            print('query had no results to fetch')
            return 1
        
    return results

# %%
query = """select * from d_locations """
run_query(query)
# Out:
# [(1, 'caltech', 'California_Garage_01', 'CA'),
#  (2, 'caltech', 'California_Garage_02', 'CA'),
#  (3, 'caltech', 'LIGO_01', 'CA'),
#  (4, 'caltech', 'N_Wilson_Garage_01', 'CA'),
#  (5, 'caltech', 'S_Wilson_Garage_01', 'CA'),
#  (6, 'jpl', 'Arroyo_Garage_01', 'CA'),
#  (7, 'office_01', 'Parking_Lot_01', 'CA')]

# %%
conn = get_connection()
with conn.cursor() as cur:
    cur.execute('SELECT version()')
    result = cur.fetchall()
    
print(result)
# Out:
# [('PostgreSQL 15.4 on x86_64-pc-linux-gnu, compiled by gcc (GCC) 7.3.1 20180712 (Red Hat 7.3.1-12), 64-bit',)]

# %% [markdown]
# ## Postgres insert helpers
#  - execute_values -> slow
#  - copy_from_stringiq -> fast

# %%
import psycopg2.extras as extras
def execute_values(conn, df, table):
    """
    Using psycopg2.extras.execute_values() to insert the dataframe
    """
    # Create a list of tupples from the dataframe values
    tuples = [tuple(x) for x in df.to_numpy()]
    # Comma-separated dataframe columns
    cols = ','.join(list(df.columns))
    # SQL quert to execute
    query  = "INSERT INTO %s(%s) VALUES %%s" % (table, cols)
    cursor = conn.cursor()
    try:
        extras.execute_values(cursor, query, tuples)
        conn.commit()
    except (Exception, psycopg2.DatabaseError) as error:
        print("Error: %s" % error)
        conn.rollback()
        cursor.close()
        return 1
    print("execute_values() done")
    cursor.close()

# %%
from io import StringIO
def copy_from_stringio(conn, df, table):
    """
    Here we are going save the dataframe in memory 
    and use copy_from() to copy it to the table
    """
    # save dataframe to an in memory buffer
    start_time = time.time()
    buffer = StringIO()
    df.to_csv(buffer,
              index=False, 
              sep=',',
              na_rep='NaN',
              header=False)
    
    buffer.seek(0)
    
    cursor = conn.cursor()
    try:
        cursor.copy_from(buffer, table, sep=",", columns=list(df.columns))
        conn.commit()
    except (Exception, psycopg2.DatabaseError) as error:
        print("Error: %s" % error)
        conn.rollback()
        cursor.close()
        return 1
    print(f'time to upload {df.shape[0]:,} records: {time.time()-start_time} or a rate of {np.round(df.shape[0]/(time.time()-start_time),-1):,}  records per second')
    print("copy_from_stringio() done")
    cursor.close()

# %% [markdown]
# # get locations

# %%
ldf = pd.read_sql(
    'select * from d_locations', conn
)
ldf.head()
# Out:
# /tmp/ipykernel_465480/3186539265.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   ldf = pd.read_sql(
#    id major_name            minor_name state
# 0   1    caltech  California_Garage_01    CA
# 1   2    caltech  California_Garage_02    CA
# 2   3    caltech               LIGO_01    CA
# 3   4    caltech    N_Wilson_Garage_01    CA
# 4   5    caltech    S_Wilson_Garage_01    CA

# %%
ldf['path'] = ldf[['major_name','minor_name']].apply(lambda x: '/'+'/'.join([x[0],x[1]])+'/', axis=1)
# Out:
# /tmp/ipykernel_465480/3597101551.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ldf['path'] = ldf[['major_name','minor_name']].apply(lambda x: '/'+'/'.join([x[0],x[1]])+'/', axis=1)

# %% [markdown]
# # Get all the files

# %%
def populate_d_files(conn, HOME_PATH):
    root = HOME_PATH + '/data/'
    rows = []
    i=0
    print(f'walking {root} for csv files ...')
    for path, subdirs, files in os.walk(root):
        for name in files:
            if name.endswith('.csv'):
                i += 1
                rows.extend([[i,os.path.join(path, name)[43:], name]])
    
    fdf = pd.DataFrame(rows, columns=['id','full_path','filename'])
    print('walk complete. \nresetting db tables...')
    query = """drop table if exists d_files;
        create table d_files
        (
            id        serial
                primary key,
            full_path varchar,
            filename  varchar
        );"""
    
    run_query(query)
    print('d_files table reset.')
    print(f'inserting {fdf.shape[0]:,} records...')
    copy_from_stringio(conn, fdf, 'd_files')
    # copy_from_stringio(conn, fdf.set_index('id'), 'd_files')
    print('file table creation complete')
    return fdf
    
fdf = populate_d_files(conn, HOME_PATH)
# Out:
# walking /home/denny/Documents/mids/ev_charging/data/ for csv files ...
# walk complete.
# resetting db tables...
# query had no results to fetch
# d_files table reset.
# inserting 85,877 records...
# time to upload 85,877 records: 8.594522714614868 or a rate of 9,990.0  records per second
# copy_from_stringio() done
# file table creation complete

# %% [markdown]
# # Insert time series charges

# %%
# # https://stackoverflow.com/a/75756749/6432367
# import csv
# import glob
# import pandas as pd
# 
# rows = []
# full_path = '/data/ACN-Data-Static-main/office_01/Parking_Lot_01/'
# file_names = []
# for filename in glob.glob("*.csv"):
#     with open(filename, newline="") as f:
#         reader = csv.reader(f)
#         columns = next(reader)
#         for row in reader:
#             if row:
#                 row += [filename]
#                 rows.append(row)
#         # columns = next(reader)
#         # rows.extend(reader)
#         # file_names += [filename] * reader.line_num
#         
# columns = ['','Charging Current (A)', 'Actual Pilot (A)', 'Voltage (V)','Charging State','Energy Delivered (kWh)', 'Power (kW)','filename']
# df = pd.DataFrame(rows, columns=columns)

# %%
def get_csvs(path):
    os.chdir(path)
    return [filename for filename in glob.glob("*.csv")]

# %%
def filename_csvs_to_df(path, filenames):
    start_time = time.time()
    new_time = start_time
    os.chdir(path)
    
    rows = []
    i = 0
    for filename in filenames:
        i +=1
        with open(filename, newline="") as f:
            reader = csv.reader(f)
            columns = next(reader)
            for row in reader:
                if row:
                    row += [filename]
                    rows.append(row)
            # columns = next(reader)
            # rows.extend(reader)
            # file_names += [filename] * reader.line_num
        if i%500==0: 
            print(f'processed {i} \t\t{time.time()-new_time}')
            new_time = time.time()
        
    print(f'time to read files:\t {time.time() - start_time}')
    new_time = time.time()
    columns = ['','Charging Current (A)', 'Actual Pilot (A)', 'Voltage (V)','Charging State','Energy Delivered (kWh)', 'Power (kW)','filename']
    df = pd.DataFrame(rows, columns=columns)
    print(f'time to make dataframe:\t {time.time() - new_time}')
    print(f'total time to parse csvs {time.time() - start_time} in {path}')
    return df

# %%
def dir_csvs_to_df(path):
    start_time = time.time()
    new_time = start_time
    os.chdir(path)
    
    rows = []
    i = 0
    for filename in glob.glob("*.csv"):
        i +=1
        with open(filename, newline="") as f:
            reader = csv.reader(f)
            columns = next(reader)
            for row in reader:
                if row:
                    row += [filename]
                    rows.append(row)
            # columns = next(reader)
            # rows.extend(reader)
            # file_names += [filename] * reader.line_num
        if i%500==0: print(f'processed {i}')
    print(f'time to read files:\t {time.time() - new_time}')
    new_time = time.time()
    columns = ['','Charging Current (A)', 'Actual Pilot (A)', 'Voltage (V)','Charging State','Energy Delivered (kWh)', 'Power (kW)','filename']
    df = pd.DataFrame(rows, columns=columns)
    print(f'time to make dataframe:\t {time.time() - new_time}')
    print(f'total time to parse csvs {time.time() - start_time} in {path}')
    return df

# %%
def format_charges(df):
    start_time = time.time()
    new_time = start_time
    
    # rename columns to match db
    df.rename(columns={"":"datetime",'Charging Current (A)':'charging_current_amps', 'Actual Pilot (A)':'actual_pilot_amps', 'Voltage (V)':'voltage_volts',
           'Charging State':'charging_state', 'Energy Delivered (kWh)':'energy_delivered_kwh', 'Power (kW)':'power_kw','filename':'file_id'}, inplace=True)
    print(f'rename columns:\t {time.time()-new_time}')
    new_time = time.time()
    
    # map location and files to foreign key ids
    # https://stackoverflow.com/a/46049755/6432367
    df['location_id'] = location_id
    
    df['file_id'] = df['file_id'].map(fdf.set_index('filename')['id'])
    print(f'mapping:\t {time.time()-new_time}')
    new_time = time.time()
    
    # add nans to empty numeric fields
    # df[['charging_current_amps','actual_pilot_amps','voltage_volts','energy_delivered_kwh','power_kw']] = df[['charging_current_amps','actual_pilot_amps','voltage_volts','energy_delivered_kwh','power_kw']].apply(pd.to_numeric, errors='coerce', axis=1)
    for col in ['charging_current_amps','actual_pilot_amps','voltage_volts','energy_delivered_kwh','power_kw']:
        df[col] = pd.to_numeric(df[col], errors='coerce')
    
    print(f'to numeric:\t {time.time()-new_time}')
    new_time = time.time()
    
    # apply date transformations
    df['datetime'] = pd.to_datetime(df['datetime'], format='mixed')
    df['date'] = df['datetime'].dt.date
    df['time'] = df['datetime'].dt.time
    
    print(f'time manipulation:\t {time.time()-new_time}')
    new_time = time.time()
    
    # put columns in order
    df = df[['datetime', 'location_id', 'file_id', 'charging_current_amps', 'actual_pilot_amps', 'voltage_volts', 'charging_state', 'energy_delivered_kwh', 'power_kw', 'date', 'time']]
    print(f'reordering:\t {time.time()-new_time}')
    print(f'total formating time:\t {time.time() - start_time}')
    return df

# %%
# import concurrent.futures
# import urllib.request
# 
# URLS = ['http://www.foxnews.com/',
#         'http://www.cnn.com/',
#         'http://europe.wsj.com/',
#         'http://www.bbc.co.uk/',
#         'http://nonexistant-subdomain.python.org/']
# 
# # Retrieve a single page and report the URL and contents
# def load_url(url, timeout):
#     with urllib.request.urlopen(url, timeout=timeout) as conn:
#         return conn.read()
# 
# # We can use a with statement to ensure threads are cleaned up promptly
# with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
#     # Start the load operations and mark each future with its URL
#     future_to_url = {executor.submit(load_url, url, 60): url for url in URLS}
#     for future in concurrent.futures.as_completed(future_to_url):
#         url = future_to_url[future]
#         try:
#             data = future.result()
#         except Exception as exc:
#             print('%r generated an exception: %s' % (url, exc))
#         else:
#             print('%r page is %d bytes' % (url, len(data)))

# %%
# path = HOME_PATH+'/data/ACN-Data-Static-main/office_01/Parking_Lot_01/'
path = HOME_PATH + '/data/ACN-Data-Static-main' + ldf.loc[6,'path']
location_id = ldf.loc[6,'id']
print(location_id, path)
start_time = time.time()
for indx_loc in ldf.index:
    os.chdir(HOME_PATH)
    # if indx_loc == 0:
    path = HOME_PATH + '/data/ACN-Data-Static-main' + ldf.loc[indx_loc,'path']
    location_id = ldf.loc[indx_loc,'id']
    print(f'running location id {location_id} from path {path}...')
    filenames = get_csvs(path)
    
    print(f'num files {len(filenames):,}')
    chunksize = 100
    for chunk in range(0,len(filenames),chunksize):
        # print(chunk, len(filenames[chunk:chunk+chunksize]))
        df_unformated = filename_csvs_to_df(path, filenames[chunk:chunk+chunksize])
        df = format_charges(df_unformated)
        print('records', df.shape[0])
        copy_from_stringio(conn, df, 'f_charges')
    # df_unformated = dir_csvs_to_df(path)
    # df = format_charges(df_unformated)
    # copy_from_stringio(conn, df, 'f_charges')
    
print(f'total upload time: {time.time() - start_time}')
print('done with upload!')
# Out:
# 7 /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/office_01/Parking_Lot_01/
# running location id 1 from path /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/...
# num files 31,860
# time to read files:	 1.9893724918365479
# time to make dataframe:	 0.26788878440856934
# total time to parse csvs 2.25736927986145 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0003027915954589844
# mapping:	 0.03744220733642578
# to numeric:	 0.4818296432495117
# time manipulation:	 0.7951006889343262
# reordering:	 0.04776406288146973
# total formating time:	 1.3627381324768066
# records 606080
# time to upload 606,080 records: 44.66438698768616 or a rate of 13,570.0  records per second
# copy_from_stringio() done
# time to read files:	 1.3036041259765625
# time to make dataframe:	 0.26853132247924805
# total time to parse csvs 1.5723655223846436 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.000286102294921875
# mapping:	 0.027683258056640625
# to numeric:	 0.42963242530822754
# time manipulation:	 0.6317577362060547
# reordering:	 0.03453183174133301
# total formating time:	 1.1240901947021484
# records 533983
# time to upload 533,983 records: 39.48553395271301 or a rate of 13,520.0  records per second
# copy_from_stringio() done
# time to read files:	 0.9714820384979248
# time to make dataframe:	 0.18007445335388184
# total time to parse csvs 1.1516425609588623 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0003006458282470703
# mapping:	 0.02104043960571289
# to numeric:	 0.36978983879089355
# time manipulation:	 0.49008941650390625
# reordering:	 0.020228862762451172
# total formating time:	 0.9016540050506592
# records 487809
# time to upload 487,809 records: 35.63769268989563 or a rate of 13,690.0  records per second
# copy_from_stringio() done
# time to read files:	 0.8165853023529053
# time to make dataframe:	 0.21019458770751953
# total time to parse csvs 1.0268785953521729 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0002887248992919922
# mapping:	 0.01968979835510254
# to numeric:	 0.3828258514404297
# time manipulation:	 0.4604349136352539
# reordering:	 0.025833845138549805
# total formating time:	 0.8892674446105957
# records 478608
# time to upload 478,608 records: 34.57720232009888 or a rate of 13,840.0  records per second
# copy_from_stringio() done
# time to read files:	 0.9467568397521973
# time to make dataframe:	 0.21256709098815918
# total time to parse csvs 1.1594207286834717 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0002701282501220703
# mapping:	 0.021996736526489258
# to numeric:	 0.4115591049194336
# time manipulation:	 0.512779951095581
# reordering:	 0.023409366607666016
# total formating time:	 0.9702162742614746
# records 504415
# time to upload 504,415 records: 36.6339385509491 or a rate of 13,770.0  records per second
# copy_from_stringio() done
# time to read files:	 1.1264164447784424
# time to make dataframe:	 0.22495579719543457
# total time to parse csvs 1.3514740467071533 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0002872943878173828
# mapping:	 0.02206134796142578
# to numeric:	 0.4219639301300049
# time manipulation:	 0.5441844463348389
# reordering:	 0.021315574645996094
# total formating time:	 1.0099928379058838
# records 519714
# time to upload 519,714 records: 44.09483814239502 or a rate of 11,790.0  records per second
# copy_from_stringio() done
# time to read files:	 1.1158740520477295
# time to make dataframe:	 0.20912766456604004
# total time to parse csvs 1.3251063823699951 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00034689903259277344
# mapping:	 0.021228313446044922
# to numeric:	 0.42283105850219727
# time manipulation:	 0.5293824672698975
# reordering:	 0.020717144012451172
# total formating time:	 0.9947352409362793
# records 499711
# time to upload 499,711 records: 64.74664115905762 or a rate of 7,720.0  records per second
# copy_from_stringio() done
# time to read files:	 1.0171029567718506
# time to make dataframe:	 0.2154543399810791
# total time to parse csvs 1.2326502799987793 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0003857612609863281
# mapping:	 0.021198272705078125
# to numeric:	 0.40683746337890625
# time manipulation:	 0.5107080936431885
# reordering:	 0.021097183227539062
# total formating time:	 0.9604413509368896
# records 502125
# time to upload 502,125 records: 59.10358929634094 or a rate of 8,500.0  records per second
# copy_from_stringio() done
# time to read files:	 1.1185393333435059
# time to make dataframe:	 0.21013617515563965
# total time to parse csvs 1.3288021087646484 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0003037452697753906
# mapping:	 0.020821809768676758
# to numeric:	 0.42960619926452637
# time manipulation:	 0.5430300235748291
# reordering:	 0.02096271514892578
# total formating time:	 1.0149214267730713
# records 507931
# time to upload 507,931 records: 56.0631377696991 or a rate of 9,060.0  records per second
# copy_from_stringio() done
# time to read files:	 1.2756705284118652
# time to make dataframe:	 0.22646236419677734
# total time to parse csvs 1.5022456645965576 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0003116130828857422
# mapping:	 0.020778656005859375
# to numeric:	 0.44538235664367676
# time manipulation:	 0.5516300201416016
# reordering:	 0.0221254825592041
# total formating time:	 1.0404002666473389
# records 519777
# time to upload 519,777 records: 67.25412082672119 or a rate of 7,730.0  records per second
# copy_from_stringio() done
# time to read files:	 1.1727957725524902
# time to make dataframe:	 0.21332287788391113
# total time to parse csvs 1.386216640472412 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00027441978454589844
# mapping:	 0.0209958553314209
# to numeric:	 0.41338276863098145
# time manipulation:	 0.5313048362731934
# reordering:	 0.020601272583007812
# total formating time:	 0.9870362281799316
# records 501468
# time to upload 501,468 records: 44.24987721443176 or a rate of 11,330.0  records per second
# copy_from_stringio() done
# time to read files:	 1.0727691650390625
# time to make dataframe:	 0.183424711227417
# total time to parse csvs 1.2562987804412842 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00047516822814941406
# mapping:	 0.020471572875976562
# to numeric:	 0.38588953018188477
# time manipulation:	 0.46143531799316406
# reordering:	 0.01941061019897461
# total formating time:	 0.887904167175293
# records 436480
# time to upload 436,480 records: 32.10779547691345 or a rate of 13,590.0  records per second
# copy_from_stringio() done
# time to read files:	 1.0863120555877686
# time to make dataframe:	 0.19548964500427246
# total time to parse csvs 1.2819087505340576 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0003304481506347656
# mapping:	 0.021951675415039062
# to numeric:	 0.38791465759277344
# time manipulation:	 0.47374486923217773
# reordering:	 0.01938152313232422
# total formating time:	 0.9035327434539795
# records 454587
# time to upload 454,587 records: 33.414084911346436 or a rate of 13,600.0  records per second
# copy_from_stringio() done
# time to read files:	 1.372802495956421
# time to make dataframe:	 0.2431488037109375
# total time to parse csvs 1.6160666942596436 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00029468536376953125
# mapping:	 0.022974014282226562
# to numeric:	 0.45934462547302246
# time manipulation:	 0.6101617813110352
# reordering:	 0.022803783416748047
# total formating time:	 1.1157622337341309
# records 554279
# time to upload 554,279 records: 40.74477672576904 or a rate of 13,600.0  records per second
# copy_from_stringio() done
# time to read files:	 1.1334683895111084
# time to make dataframe:	 0.2177410125732422
# total time to parse csvs 1.3513116836547852 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0002944469451904297
# mapping:	 0.021892786026000977
# to numeric:	 0.4313342571258545
# time manipulation:	 0.5150060653686523
# reordering:	 0.020612478256225586
# total formating time:	 0.989372968673706
# records 482757
# time to upload 482,757 records: 35.6534698009491 or a rate of 13,540.0  records per second
# copy_from_stringio() done
# time to read files:	 1.0430526733398438
# time to make dataframe:	 0.20269441604614258
# total time to parse csvs 1.2458462715148926 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00026917457580566406
# mapping:	 0.020446300506591797
# to numeric:	 0.4146761894226074
# time manipulation:	 0.5094451904296875
# reordering:	 0.020523786544799805
# total formating time:	 0.9655537605285645
# records 487044
# time to upload 487,044 records: 36.08248281478882 or a rate of 13,500.0  records per second
# copy_from_stringio() done
# time to read files:	 1.1338775157928467
# time to make dataframe:	 0.21495962142944336
# total time to parse csvs 1.3489360809326172 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00029468536376953125
# mapping:	 0.021558046340942383
# to numeric:	 0.41046929359436035
# time manipulation:	 0.5297000408172607
# reordering:	 0.020700693130493164
# total formating time:	 0.9829375743865967
# records 504830
# time to upload 504,830 records: 39.2904839515686 or a rate of 12,850.0  records per second
# copy_from_stringio() done
# time to read files:	 1.2230145931243896
# time to make dataframe:	 0.21550655364990234
# total time to parse csvs 1.4386200904846191 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0003170967102050781
# mapping:	 0.023831605911254883
# to numeric:	 0.40136051177978516
# time manipulation:	 0.49544811248779297
# reordering:	 0.020464420318603516
# total formating time:	 0.9416429996490479
# records 459849
# time to upload 459,849 records: 33.783034563064575 or a rate of 13,610.0  records per second
# copy_from_stringio() done
# time to read files:	 1.2358016967773438
# time to make dataframe:	 0.22430777549743652
# total time to parse csvs 1.4602124691009521 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0002789497375488281
# mapping:	 0.022318601608276367
# to numeric:	 0.4365506172180176
# time manipulation:	 0.5580847263336182
# reordering:	 0.023343563079833984
# total formating time:	 1.0408661365509033
# records 555133
# time to upload 555,133 records: 41.216517210006714 or a rate of 13,470.0  records per second
# copy_from_stringio() done
# time to read files:	 1.2367525100708008
# time to make dataframe:	 0.21021676063537598
# total time to parse csvs 1.4470741748809814 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0003314018249511719
# mapping:	 0.020055294036865234
# to numeric:	 0.4080953598022461
# time manipulation:	 0.5110130310058594
# reordering:	 0.019399642944335938
# total formating time:	 0.9593908786773682
# records 488788
# time to upload 488,788 records: 36.05879306793213 or a rate of 13,560.0  records per second
# copy_from_stringio() done
# time to read files:	 1.1459615230560303
# time to make dataframe:	 0.2253398895263672
# total time to parse csvs 1.3714053630828857 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0003018379211425781
# mapping:	 0.020838260650634766
# to numeric:	 0.44335079193115234
# time manipulation:	 0.5625813007354736
# reordering:	 0.02163076400756836
# total formating time:	 1.048896074295044
# records 515684
# time to upload 515,684 records: 37.79391312599182 or a rate of 13,640.0  records per second
# copy_from_stringio() done
# time to read files:	 1.1749968528747559
# time to make dataframe:	 0.19382667541503906
# total time to parse csvs 1.3689215183258057 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0002760887145996094
# mapping:	 0.020101308822631836
# to numeric:	 0.3696470260620117
# time manipulation:	 0.4853382110595703
# reordering:	 0.019536972045898438
# total formating time:	 0.8951008319854736
# records 463801
# time to upload 463,801 records: 34.061729431152344 or a rate of 13,620.0  records per second
# copy_from_stringio() done
# time to read files:	 1.1440486907958984
# time to make dataframe:	 0.20115947723388672
# total time to parse csvs 1.3453073501586914 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0002887248992919922
# mapping:	 0.022185802459716797
# to numeric:	 0.420609712600708
# time manipulation:	 0.5070252418518066
# reordering:	 0.020685911178588867
# total formating time:	 0.9710025787353516
# records 477485
# time to upload 477,485 records: 34.84510254859924 or a rate of 13,700.0  records per second
# copy_from_stringio() done
# time to read files:	 1.0938985347747803
# time to make dataframe:	 0.18901538848876953
# total time to parse csvs 1.283015489578247 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0003058910369873047
# mapping:	 0.021149396896362305
# to numeric:	 0.37700629234313965
# time manipulation:	 0.4707450866699219
# reordering:	 0.019277572631835938
# total formating time:	 0.8887343406677246
# records 447150
# time to upload 447,150 records: 32.77312421798706 or a rate of 13,640.0  records per second
# copy_from_stringio() done
# time to read files:	 1.0539488792419434
# time to make dataframe:	 0.18461060523986816
# total time to parse csvs 1.2386624813079834 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00027251243591308594
# mapping:	 0.02208256721496582
# to numeric:	 0.3679473400115967
# time manipulation:	 0.4733436107635498
# reordering:	 0.0186309814453125
# total formating time:	 0.8824672698974609
# records 450246
# time to upload 450,246 records: 32.70720458030701 or a rate of 13,770.0  records per second
# copy_from_stringio() done
# time to read files:	 1.0554487705230713
# time to make dataframe:	 0.21109461784362793
# total time to parse csvs 1.2666430473327637 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0003991127014160156
# mapping:	 0.020655393600463867
# to numeric:	 0.37061047554016113
# time manipulation:	 0.4981224536895752
# reordering:	 0.027760982513427734
# total formating time:	 0.9177711009979248
# records 475657
# time to upload 475,657 records: 34.703285455703735 or a rate of 13,710.0  records per second
# copy_from_stringio() done
# time to read files:	 1.4100115299224854
# time to make dataframe:	 0.26413536071777344
# total time to parse csvs 1.674323558807373 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0002751350402832031
# mapping:	 0.02681136131286621
# to numeric:	 0.49849963188171387
# time manipulation:	 0.7221088409423828
# reordering:	 0.029566526412963867
# total formating time:	 1.277498483657837
# records 647911
# time to upload 647,911 records: 47.14343523979187 or a rate of 13,740.0  records per second
# copy_from_stringio() done
# time to read files:	 1.4894678592681885
# time to make dataframe:	 0.2399439811706543
# total time to parse csvs 1.7295243740081787 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0002837181091308594
# mapping:	 0.02270984649658203
# to numeric:	 0.48273420333862305
# time manipulation:	 0.6315772533416748
# reordering:	 0.025038480758666992
# total formating time:	 1.1625285148620605
# records 563062
# time to upload 563,062 records: 41.345096826553345 or a rate of 13,620.0  records per second
# copy_from_stringio() done
# time to read files:	 1.2620654106140137
# time to make dataframe:	 0.23155808448791504
# total time to parse csvs 1.4937536716461182 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0002770423889160156
# mapping:	 0.022624731063842773
# to numeric:	 0.4542202949523926
# time manipulation:	 0.6079089641571045
# reordering:	 0.022910594940185547
# total formating time:	 1.1081149578094482
# records 547692
# time to upload 547,692 records: 40.81968593597412 or a rate of 13,420.0  records per second
# copy_from_stringio() done
# time to read files:	 1.40683913230896
# time to make dataframe:	 0.23035955429077148
# total time to parse csvs 1.637436866760254 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0002734661102294922
# mapping:	 0.02294611930847168
# to numeric:	 0.48306941986083984
# time manipulation:	 0.626063346862793
# reordering:	 0.027000904083251953
# total formating time:	 1.1595396995544434
# records 551515
# time to upload 551,515 records: 40.477355003356934 or a rate of 13,630.0  records per second
# copy_from_stringio() done
# time to read files:	 0.93100905418396
# time to make dataframe:	 0.20684242248535156
# total time to parse csvs 1.1379642486572266 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00034999847412109375
# mapping:	 0.022674560546875
# to numeric:	 0.41426849365234375
# time manipulation:	 0.540259838104248
# reordering:	 0.023952722549438477
# total formating time:	 1.0017597675323486
# records 470886
# time to upload 470,886 records: 34.588167667388916 or a rate of 13,610.0  records per second
# copy_from_stringio() done
# time to read files:	 1.1541991233825684
# time to make dataframe:	 0.21302556991577148
# total time to parse csvs 1.367323398590088 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0002770423889160156
# mapping:	 0.022047996520996094
# to numeric:	 0.44678306579589844
# time manipulation:	 0.5626306533813477
# reordering:	 0.021712541580200195
# total formating time:	 1.0537347793579102
# records 516971
# time to upload 516,971 records: 37.65375566482544 or a rate of 13,730.0  records per second
# copy_from_stringio() done
# time to read files:	 1.1329762935638428
# time to make dataframe:	 0.20015573501586914
# total time to parse csvs 1.3332288265228271 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0002753734588623047
# mapping:	 0.02312016487121582
# to numeric:	 0.400146484375
# time manipulation:	 0.5008270740509033
# reordering:	 0.024220943450927734
# total formating time:	 0.9488224983215332
# records 454741
# time to upload 454,741 records: 33.484596252441406 or a rate of 13,580.0  records per second
# copy_from_stringio() done
# time to read files:	 1.0670292377471924
# time to make dataframe:	 0.19760870933532715
# total time to parse csvs 1.2647380828857422 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00041103363037109375
# mapping:	 0.020397186279296875
# to numeric:	 0.40331053733825684
# time manipulation:	 0.48337721824645996
# reordering:	 0.019600391387939453
# total formating time:	 0.9273107051849365
# records 472772
# time to upload 472,772 records: 34.89006590843201 or a rate of 13,550.0  records per second
# copy_from_stringio() done
# time to read files:	 1.43719482421875
# time to make dataframe:	 0.24997663497924805
# total time to parse csvs 1.687302827835083 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.000301361083984375
# mapping:	 0.023923158645629883
# to numeric:	 0.49257826805114746
# time manipulation:	 0.6655745506286621
# reordering:	 0.03602933883666992
# total formating time:	 1.2185866832733154
# records 606472
# time to upload 606,472 records: 45.028315782547 or a rate of 13,470.0  records per second
# copy_from_stringio() done
# time to read files:	 1.3310821056365967
# time to make dataframe:	 0.2510561943054199
# total time to parse csvs 1.5822358131408691 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0003159046173095703
# mapping:	 0.02418231964111328
# to numeric:	 0.4777956008911133
# time manipulation:	 0.6052825450897217
# reordering:	 0.023428916931152344
# total formating time:	 1.131202220916748
# records 564717
# time to upload 564,717 records: 41.59016251564026 or a rate of 13,580.0  records per second
# copy_from_stringio() done
# time to read files:	 1.3160114288330078
# time to make dataframe:	 0.2619166374206543
# total time to parse csvs 1.5780773162841797 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0003018379211425781
# mapping:	 0.022034883499145508
# to numeric:	 0.4661116600036621
# time manipulation:	 0.6050570011138916
# reordering:	 0.025204181671142578
# total formating time:	 1.1188931465148926
# records 584664
# time to upload 584,664 records: 42.968011140823364 or a rate of 13,610.0  records per second
# copy_from_stringio() done
# time to read files:	 1.1985626220703125
# time to make dataframe:	 0.23340582847595215
# total time to parse csvs 1.4323763847351074 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0002865791320800781
# mapping:	 0.021790504455566406
# to numeric:	 0.4652676582336426
# time manipulation:	 0.6053905487060547
# reordering:	 0.024442195892333984
# total formating time:	 1.1173748970031738
# records 538999
# time to upload 538,999 records: 40.16425681114197 or a rate of 13,420.0  records per second
# copy_from_stringio() done
# time to read files:	 1.126025915145874
# time to make dataframe:	 0.2140822410583496
# total time to parse csvs 1.3402118682861328 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0003008842468261719
# mapping:	 0.022336483001708984
# to numeric:	 0.43039894104003906
# time manipulation:	 0.5302691459655762
# reordering:	 0.02052903175354004
# total formating time:	 1.0040667057037354
# records 512990
# time to upload 512,990 records: 37.51796007156372 or a rate of 13,670.0  records per second
# copy_from_stringio() done
# time to read files:	 1.200969934463501
# time to make dataframe:	 0.2088029384613037
# total time to parse csvs 1.4098832607269287 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00028514862060546875
# mapping:	 0.019573211669921875
# to numeric:	 0.4027390480041504
# time manipulation:	 0.500068187713623
# reordering:	 0.01960611343383789
# total formating time:	 0.9424512386322021
# records 474435
# time to upload 474,435 records: 35.332377672195435 or a rate of 13,430.0  records per second
# copy_from_stringio() done
# time to read files:	 1.188781499862671
# time to make dataframe:	 0.2098848819732666
# total time to parse csvs 1.3987891674041748 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00035262107849121094
# mapping:	 0.02226567268371582
# to numeric:	 0.42347002029418945
# time manipulation:	 0.5074863433837891
# reordering:	 0.021704912185668945
# total formating time:	 0.975651741027832
# records 483110
# time to upload 483,110 records: 35.71576261520386 or a rate of 13,530.0  records per second
# copy_from_stringio() done
# time to read files:	 1.0191233158111572
# time to make dataframe:	 0.2038416862487793
# total time to parse csvs 1.2230589389801025 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00026106834411621094
# mapping:	 0.019964933395385742
# to numeric:	 0.3928358554840088
# time manipulation:	 0.49004268646240234
# reordering:	 0.0219113826751709
# total formating time:	 0.9252259731292725
# records 474290
# time to upload 474,290 records: 34.93369126319885 or a rate of 13,580.0  records per second
# copy_from_stringio() done
# time to read files:	 1.255594253540039
# time to make dataframe:	 0.2549004554748535
# total time to parse csvs 1.5106215476989746 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0005843639373779297
# mapping:	 0.024953603744506836
# to numeric:	 0.5007662773132324
# time manipulation:	 0.6287596225738525
# reordering:	 0.02901911735534668
# total formating time:	 1.1842949390411377
# records 556514
# time to upload 556,514 records: 41.47736644744873 or a rate of 13,420.0  records per second
# copy_from_stringio() done
# time to read files:	 1.60799241065979
# time to make dataframe:	 0.2980477809906006
# total time to parse csvs 1.9061822891235352 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0002968311309814453
# mapping:	 0.026241302490234375
# to numeric:	 0.5689527988433838
# time manipulation:	 0.7683570384979248
# reordering:	 0.03234076499938965
# total formating time:	 1.396409034729004
# records 686704
# time to upload 686,704 records: 50.28934860229492 or a rate of 13,660.0  records per second
# copy_from_stringio() done
# time to read files:	 1.172884464263916
# time to make dataframe:	 0.19800209999084473
# total time to parse csvs 1.3709783554077148 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00028133392333984375
# mapping:	 0.02077484130859375
# to numeric:	 0.39223432540893555
# time manipulation:	 0.5037026405334473
# reordering:	 0.020099878311157227
# total formating time:	 0.9373137950897217
# records 451067
# time to upload 451,067 records: 33.18655443191528 or a rate of 13,590.0  records per second
# copy_from_stringio() done
# time to read files:	 1.1219000816345215
# time to make dataframe:	 0.20090579986572266
# total time to parse csvs 1.3229024410247803 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00028443336486816406
# mapping:	 0.021173477172851562
# to numeric:	 0.4258460998535156
# time manipulation:	 0.5314946174621582
# reordering:	 0.020947694778442383
# total formating time:	 1.0001769065856934
# records 499608
# time to upload 499,608 records: 38.286438941955566 or a rate of 13,050.0  records per second
# copy_from_stringio() done
# time to read files:	 0.9901347160339355
# time to make dataframe:	 0.20550084114074707
# total time to parse csvs 1.1957859992980957 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00029277801513671875
# mapping:	 0.02046799659729004
# to numeric:	 0.3923201560974121
# time manipulation:	 0.48864269256591797
# reordering:	 0.021007537841796875
# total formating time:	 0.9229452610015869
# records 452979
# time to upload 452,979 records: 34.98927879333496 or a rate of 12,950.0  records per second
# copy_from_stringio() done
# time to read files:	 1.1857514381408691
# time to make dataframe:	 0.2142927646636963
# total time to parse csvs 1.4001502990722656 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0002739429473876953
# mapping:	 0.02347540855407715
# to numeric:	 0.44207167625427246
# time manipulation:	 0.561805009841919
# reordering:	 0.022086143493652344
# total formating time:	 1.0499076843261719
# records 524140
# time to upload 524,140 records: 39.755491733551025 or a rate of 13,180.0  records per second
# copy_from_stringio() done
# time to read files:	 1.266798734664917
# time to make dataframe:	 0.2329730987548828
# total time to parse csvs 1.499894618988037 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00026917457580566406
# mapping:	 0.02186274528503418
# to numeric:	 0.4606785774230957
# time manipulation:	 0.6303014755249023
# reordering:	 0.022784709930419922
# total formating time:	 1.13606595993042
# records 564938
# time to upload 564,938 records: 42.96308183670044 or a rate of 13,150.0  records per second
# copy_from_stringio() done
# time to read files:	 1.2561225891113281
# time to make dataframe:	 0.24469971656799316
# total time to parse csvs 1.5009174346923828 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0002758502960205078
# mapping:	 0.025450468063354492
# to numeric:	 0.46276259422302246
# time manipulation:	 0.5866332054138184
# reordering:	 0.024467945098876953
# total formating time:	 1.0998070240020752
# records 549441
# time to upload 549,441 records: 42.13414525985718 or a rate of 13,040.0  records per second
# copy_from_stringio() done
# time to read files:	 1.2205352783203125
# time to make dataframe:	 0.2142019271850586
# total time to parse csvs 1.4348573684692383 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00041794776916503906
# mapping:	 0.02205371856689453
# to numeric:	 0.4317169189453125
# time manipulation:	 0.5180206298828125
# reordering:	 0.020282506942749023
# total formating time:	 0.9926960468292236
# records 485873
# time to upload 485,873 records: 36.62887477874756 or a rate of 13,260.0  records per second
# copy_from_stringio() done
# time to read files:	 1.0897347927093506
# time to make dataframe:	 0.22650766372680664
# total time to parse csvs 1.3163604736328125 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00027298927307128906
# mapping:	 0.023672819137573242
# to numeric:	 0.4362771511077881
# time manipulation:	 0.5574393272399902
# reordering:	 0.021862268447875977
# total formating time:	 1.0396974086761475
# records 502784
# time to upload 502,784 records: 37.83568072319031 or a rate of 13,290.0  records per second
# copy_from_stringio() done
# time to read files:	 0.942702054977417
# time to make dataframe:	 0.19145607948303223
# total time to parse csvs 1.134272813796997 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00029659271240234375
# mapping:	 0.01978135108947754
# to numeric:	 0.378354549407959
# time manipulation:	 0.46672773361206055
# reordering:	 0.02040886878967285
# total formating time:	 0.8857595920562744
# records 438847
# time to upload 438,847 records: 32.95280122756958 or a rate of 13,320.0  records per second
# copy_from_stringio() done
# time to read files:	 1.5000710487365723
# time to make dataframe:	 0.2470710277557373
# total time to parse csvs 1.747269868850708 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00027298927307128906
# mapping:	 0.02534031867980957
# to numeric:	 0.4501945972442627
# time manipulation:	 0.6326541900634766
# reordering:	 0.027904033660888672
# total formating time:	 1.1365563869476318
# records 575090
# time to upload 575,090 records: 45.17243051528931 or a rate of 12,730.0  records per second
# copy_from_stringio() done
# time to read files:	 1.6804077625274658
# time to make dataframe:	 0.2871363162994385
# total time to parse csvs 1.9676721096038818 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0002887248992919922
# mapping:	 0.026467561721801758
# to numeric:	 0.5465736389160156
# time manipulation:	 0.7521584033966064
# reordering:	 0.03223299980163574
# total formating time:	 1.3579487800598145
# records 665366
# time to upload 665,366 records: 53.170612812042236 or a rate of 12,510.0  records per second
# copy_from_stringio() done
# time to read files:	 1.2122056484222412
# time to make dataframe:	 0.23860692977905273
# total time to parse csvs 1.4509084224700928 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00026679039001464844
# mapping:	 0.022999048233032227
# to numeric:	 0.45423054695129395
# time manipulation:	 0.5576245784759521
# reordering:	 0.022334814071655273
# total formating time:	 1.0576577186584473
# records 526201
# time to upload 526,201 records: 40.12174367904663 or a rate of 13,120.0  records per second
# copy_from_stringio() done
# time to read files:	 0.9472520351409912
# time to make dataframe:	 0.19518804550170898
# total time to parse csvs 1.1440725326538086 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00036406517028808594
# mapping:	 0.022796630859375
# to numeric:	 0.3639092445373535
# time manipulation:	 0.4356870651245117
# reordering:	 0.0192105770111084
# total formating time:	 0.842266321182251
# records 446577
# time to upload 446,577 records: 35.56359362602234 or a rate of 12,560.0  records per second
# copy_from_stringio() done
# time to read files:	 1.2168083190917969
# time to make dataframe:	 0.21898388862609863
# total time to parse csvs 1.4359006881713867 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0003821849822998047
# mapping:	 0.021693944931030273
# to numeric:	 0.4226374626159668
# time manipulation:	 0.5118396282196045
# reordering:	 0.02187967300415039
# total formating time:	 0.9786374568939209
# records 478192
# time to upload 478,192 records: 38.38571500778198 or a rate of 12,460.0  records per second
# copy_from_stringio() done
# time to read files:	 1.1564056873321533
# time to make dataframe:	 0.21285581588745117
# total time to parse csvs 1.3693642616271973 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0003082752227783203
# mapping:	 0.020975112915039062
# to numeric:	 0.41137003898620605
# time manipulation:	 0.5138852596282959
# reordering:	 0.021061182022094727
# total formating time:	 0.9678201675415039
# records 490841
# time to upload 490,841 records: 38.361472845077515 or a rate of 12,800.0  records per second
# copy_from_stringio() done
# time to read files:	 0.9578042030334473
# time to make dataframe:	 0.18969440460205078
# total time to parse csvs 1.1476030349731445 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0003006458282470703
# mapping:	 0.02002096176147461
# to numeric:	 0.3731503486633301
# time manipulation:	 0.47406578063964844
# reordering:	 0.01859569549560547
# total formating time:	 0.8863513469696045
# records 447480
# time to upload 447,480 records: 35.73126745223999 or a rate of 12,520.0  records per second
# copy_from_stringio() done
# time to read files:	 1.224275827407837
# time to make dataframe:	 0.19595718383789062
# total time to parse csvs 1.420334815979004 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00026416778564453125
# mapping:	 0.02241826057434082
# to numeric:	 0.39877820014953613
# time manipulation:	 0.49399495124816895
# reordering:	 0.018791675567626953
# total formating time:	 0.9345417022705078
# records 464228
# time to upload 464,228 records: 35.364240884780884 or a rate of 13,130.0  records per second
# copy_from_stringio() done
# time to read files:	 1.5094451904296875
# time to make dataframe:	 0.24177980422973633
# total time to parse csvs 1.7514634132385254 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.000335693359375
# mapping:	 0.02385091781616211
# to numeric:	 0.48963332176208496
# time manipulation:	 0.6663084030151367
# reordering:	 0.03090071678161621
# total formating time:	 1.2112181186676025
# records 597618
# time to upload 597,618 records: 45.87450289726257 or a rate of 13,030.0  records per second
# copy_from_stringio() done
# time to read files:	 1.3795733451843262
# time to make dataframe:	 0.2621877193450928
# total time to parse csvs 1.6418592929840088 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0002799034118652344
# mapping:	 0.023061513900756836
# to numeric:	 0.500006914138794
# time manipulation:	 0.6455862522125244
# reordering:	 0.025568246841430664
# total formating time:	 1.1947224140167236
# records 596754
# time to upload 596,754 records: 47.280264377593994 or a rate of 12,620.0  records per second
# copy_from_stringio() done
# time to read files:	 1.2597789764404297
# time to make dataframe:	 0.23673534393310547
# total time to parse csvs 1.4966342449188232 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00028967857360839844
# mapping:	 0.025581836700439453
# to numeric:	 0.4403560161590576
# time manipulation:	 0.6050426959991455
# reordering:	 0.023874759674072266
# total formating time:	 1.0953326225280762
# records 541482
# time to upload 541,482 records: 42.702566385269165 or a rate of 12,680.0  records per second
# copy_from_stringio() done
# time to read files:	 1.3044674396514893
# time to make dataframe:	 0.21891045570373535
# total time to parse csvs 1.5234825611114502 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0002982616424560547
# mapping:	 0.02282571792602539
# to numeric:	 0.4438655376434326
# time manipulation:	 0.5640583038330078
# reordering:	 0.02183222770690918
# total formating time:	 1.053144931793213
# records 521612
# time to upload 521,612 records: 42.02755832672119 or a rate of 12,410.0  records per second
# copy_from_stringio() done
# time to read files:	 1.1444244384765625
# time to make dataframe:	 0.2269132137298584
# total time to parse csvs 1.3715415000915527 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0004150867462158203
# mapping:	 0.022042036056518555
# to numeric:	 0.44081664085388184
# time manipulation:	 0.5481104850769043
# reordering:	 0.021823883056640625
# total formating time:	 1.0333921909332275
# records 498479
# time to upload 498,479 records: 38.33179783821106 or a rate of 13,000.0  records per second
# copy_from_stringio() done
# time to read files:	 1.4132492542266846
# time to make dataframe:	 0.24882817268371582
# total time to parse csvs 1.6622188091278076 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00028252601623535156
# mapping:	 0.02506256103515625
# to numeric:	 0.47547268867492676
# time manipulation:	 0.65966796875
# reordering:	 0.02386021614074707
# total formating time:	 1.184523582458496
# records 592938
# time to upload 592,938 records: 45.00562238693237 or a rate of 13,170.0  records per second
# copy_from_stringio() done
# time to read files:	 1.312593698501587
# time to make dataframe:	 0.2417125701904297
# total time to parse csvs 1.554415225982666 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0003018379211425781
# mapping:	 0.025270938873291016
# to numeric:	 0.45575833320617676
# time manipulation:	 0.6173272132873535
# reordering:	 0.022617578506469727
# total formating time:	 1.1214759349822998
# records 550250
# time to upload 550,250 records: 42.150710105895996 or a rate of 13,050.0  records per second
# copy_from_stringio() done
# time to read files:	 1.0259881019592285
# time to make dataframe:	 0.20981216430664062
# total time to parse csvs 1.2359282970428467 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0002834796905517578
# mapping:	 0.02075672149658203
# to numeric:	 0.42423558235168457
# time manipulation:	 0.5151300430297852
# reordering:	 0.021004199981689453
# total formating time:	 0.981621265411377
# records 485061
# time to upload 485,061 records: 36.7332489490509 or a rate of 13,200.0  records per second
# copy_from_stringio() done
# time to read files:	 1.5791966915130615
# time to make dataframe:	 0.2505621910095215
# total time to parse csvs 1.8298802375793457 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00027370452880859375
# mapping:	 0.02205038070678711
# to numeric:	 0.5092365741729736
# time manipulation:	 0.6634881496429443
# reordering:	 0.025802135467529297
# total formating time:	 1.2210240364074707
# records 602185
# time to upload 602,185 records: 45.32373547554016 or a rate of 13,290.0  records per second
# copy_from_stringio() done
# time to read files:	 1.1196608543395996
# time to make dataframe:	 0.19661855697631836
# total time to parse csvs 1.316380500793457 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0002720355987548828
# mapping:	 0.020626068115234375
# to numeric:	 0.3952319622039795
# time manipulation:	 0.4976212978363037
# reordering:	 0.018943071365356445
# total formating time:	 0.932995080947876
# records 455677
# time to upload 455,677 records: 35.33761954307556 or a rate of 12,890.0  records per second
# copy_from_stringio() done
# time to read files:	 1.1341962814331055
# time to make dataframe:	 0.21826910972595215
# total time to parse csvs 1.352571964263916 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0002663135528564453
# mapping:	 0.022329330444335938
# to numeric:	 0.46286511421203613
# time manipulation:	 0.5600235462188721
# reordering:	 0.020987272262573242
# total formating time:	 1.0666613578796387
# records 526582
# time to upload 526,582 records: 40.6383318901062 or a rate of 12,960.0  records per second
# copy_from_stringio() done
# time to read files:	 1.1054866313934326
# time to make dataframe:	 0.20218253135681152
# total time to parse csvs 1.3078019618988037 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00029754638671875
# mapping:	 0.0197906494140625
# to numeric:	 0.41742610931396484
# time manipulation:	 0.48888683319091797
# reordering:	 0.019013166427612305
# total formating time:	 0.9456233978271484
# records 459061
# time to upload 459,061 records: 37.29287505149841 or a rate of 12,310.0  records per second
# copy_from_stringio() done
# time to read files:	 1.3962693214416504
# time to make dataframe:	 0.2119441032409668
# total time to parse csvs 1.6083118915557861 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0003046989440917969
# mapping:	 0.021816492080688477
# to numeric:	 0.47162532806396484
# time manipulation:	 0.5579128265380859
# reordering:	 0.0211026668548584
# total formating time:	 1.0729660987854004
# records 522594
# time to upload 522,594 records: 39.515279054641724 or a rate of 13,230.0  records per second
# copy_from_stringio() done
# time to read files:	 1.2673802375793457
# time to make dataframe:	 0.24053668975830078
# total time to parse csvs 1.5080578327178955 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0002734661102294922
# mapping:	 0.020976781845092773
# to numeric:	 0.4606494903564453
# time manipulation:	 0.5571014881134033
# reordering:	 0.02264237403869629
# total formating time:	 1.0618188381195068
# records 507433
# time to upload 507,433 records: 38.40152072906494 or a rate of 13,210.0  records per second
# copy_from_stringio() done
# time to read files:	 1.3958697319030762
# time to make dataframe:	 0.2427976131439209
# total time to parse csvs 1.6387856006622314 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00026679039001464844
# mapping:	 0.024204254150390625
# to numeric:	 0.4618184566497803
# time manipulation:	 0.6037423610687256
# reordering:	 0.023130416870117188
# total formating time:	 1.1133451461791992
# records 540915
# time to upload 540,915 records: 40.919233322143555 or a rate of 13,220.0  records per second
# copy_from_stringio() done
# time to read files:	 0.8998775482177734
# time to make dataframe:	 0.16852569580078125
# total time to parse csvs 1.0685040950775146 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0002803802490234375
# mapping:	 0.018941402435302734
# to numeric:	 0.33429622650146484
# time manipulation:	 0.4168853759765625
# reordering:	 0.01666855812072754
# total formating time:	 0.787285566329956
# records 391236
# time to upload 391,236 records: 29.856831312179565 or a rate of 13,100.0  records per second
# copy_from_stringio() done
# time to read files:	 1.1110780239105225
# time to make dataframe:	 0.22864651679992676
# total time to parse csvs 1.339822769165039 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0002875328063964844
# mapping:	 0.021399736404418945
# to numeric:	 0.41770052909851074
# time manipulation:	 0.5315258502960205
# reordering:	 0.021973609924316406
# total formating time:	 0.993112325668335
# records 503461
# time to upload 503,461 records: 38.452686071395874 or a rate of 13,090.0  records per second
# copy_from_stringio() done
# time to read files:	 1.6497085094451904
# time to make dataframe:	 0.2638859748840332
# total time to parse csvs 1.9137496948242188 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00027823448181152344
# mapping:	 0.02630758285522461
# to numeric:	 0.5007660388946533
# time manipulation:	 0.7160248756408691
# reordering:	 0.03365802764892578
# total formating time:	 1.277205467224121
# records 653024
# time to upload 653,024 records: 48.78290677070618 or a rate of 13,390.0  records per second
# copy_from_stringio() done
# time to read files:	 1.2328290939331055
# time to make dataframe:	 0.21932363510131836
# total time to parse csvs 1.45225191116333 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.00029158592224121094
# mapping:	 0.023389339447021484
# to numeric:	 0.44385337829589844
# time manipulation:	 0.5642976760864258
# reordering:	 0.023674964904785156
# total formating time:	 1.0557332038879395
# records 518673
# time to upload 518,673 records: 39.38525366783142 or a rate of 13,170.0  records per second
# copy_from_stringio() done
# time to read files:	 1.3791422843933105
# time to make dataframe:	 0.2418956756591797
# total time to parse csvs 1.6211802959442139 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0003707408905029297
# mapping:	 0.02183389663696289
# to numeric:	 0.463029146194458
# time manipulation:	 0.6001944541931152
# reordering:	 0.030878067016601562
# total formating time:	 1.116506814956665
# records 545216
# time to upload 545,216 records: 41.29033660888672 or a rate of 13,200.0  records per second
# copy_from_stringio() done
# time to read files:	 1.1247508525848389
# time to make dataframe:	 0.19289588928222656
# total time to parse csvs 1.317734718322754 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.000270843505859375
# mapping:	 0.022374629974365234
# to numeric:	 0.38988685607910156
# time manipulation:	 0.4845864772796631
# reordering:	 0.019368648529052734
# total formating time:	 0.9166779518127441
# records 452128
# time to upload 452,128 records: 34.43478298187256 or a rate of 13,130.0  records per second
# copy_from_stringio() done
# time to read files:	 1.1668250560760498
# time to make dataframe:	 0.1988832950592041
# total time to parse csvs 1.3658125400543213 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/caltech/California_Garage_01/
# rename columns:	 0.0002560615539550781
# mapping:	 0.021519184112548828
# to numeric:	 0.405153751373291
# time manipulation:	 0.4860267639160156
# reordering:	 0.018926620483398438
# total formating time:	 0.9320893287658691
# records 456292
# ...
# rename columns:	 0.0003528594970703125
# mapping:	 0.03951835632324219
# to numeric:	 0.30115652084350586
# time manipulation:	 0.6814348697662354
# reordering:	 0.0208737850189209
# total formating time:	 1.0435945987701416
# records 625517
# time to upload 625,517 records: 44.00273561477661 or a rate of 14,220.0  records per second
# copy_from_stringio() done
# time to read files:	 1.1775782108306885
# time to make dataframe:	 0.21338129043579102
# total time to parse csvs 1.391096830368042 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/jpl/Arroyo_Garage_01/
# rename columns:	 0.0003600120544433594
# mapping:	 0.03882193565368652
# to numeric:	 0.2972843647003174
# time manipulation:	 0.6741259098052979
# reordering:	 0.01965618133544922
# total formating time:	 1.030564546585083
# records 602911
# time to upload 602,911 records: 41.60419321060181 or a rate of 14,490.0  records per second
# copy_from_stringio() done
# time to read files:	 1.2474095821380615
# time to make dataframe:	 0.2308950424194336
# total time to parse csvs 1.478433609008789 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/jpl/Arroyo_Garage_01/
# rename columns:	 0.0003619194030761719
# mapping:	 0.04404950141906738
# to numeric:	 0.3328118324279785
# time manipulation:	 0.6742942333221436
# reordering:	 0.021614551544189453
# total formating time:	 1.0733897686004639
# records 617702
# time to upload 617,702 records: 38.62260890007019 or a rate of 15,990.0  records per second
# copy_from_stringio() done
# time to read files:	 1.4931731224060059
# time to make dataframe:	 0.259824275970459
# total time to parse csvs 1.7531166076660156 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/jpl/Arroyo_Garage_01/
# rename columns:	 0.0003986358642578125
# mapping:	 0.038860321044921875
# to numeric:	 0.3313429355621338
# time manipulation:	 0.6706047058105469
# reordering:	 0.021448373794555664
# total formating time:	 1.062934160232544
# records 609958
# time to upload 609,958 records: 40.29496431350708 or a rate of 15,140.0  records per second
# copy_from_stringio() done
# time to read files:	 1.1739616394042969
# time to make dataframe:	 0.22411394119262695
# total time to parse csvs 1.3982067108154297 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/jpl/Arroyo_Garage_01/
# rename columns:	 0.00037860870361328125
# mapping:	 0.0428314208984375
# to numeric:	 0.3205268383026123
# time manipulation:	 0.6695594787597656
# reordering:	 0.02181529998779297
# total formating time:	 1.055375576019287
# records 613014
# time to upload 613,014 records: 39.23828887939453 or a rate of 15,620.0  records per second
# copy_from_stringio() done
# time to read files:	 1.4887683391571045
# time to make dataframe:	 0.24386930465698242
# total time to parse csvs 1.7328155040740967 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/jpl/Arroyo_Garage_01/
# rename columns:	 0.00040221214294433594
# mapping:	 0.04163837432861328
# to numeric:	 0.3194103240966797
# time manipulation:	 0.7323629856109619
# reordering:	 0.02727818489074707
# total formating time:	 1.1213316917419434
# records 649996
# time to upload 649,996 records: 39.785240650177 or a rate of 16,340.0  records per second
# copy_from_stringio() done
# time to read files:	 1.3586466312408447
# time to make dataframe:	 0.2225170135498047
# total time to parse csvs 1.5813066959381104 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/jpl/Arroyo_Garage_01/
# rename columns:	 0.0003535747528076172
# mapping:	 0.03781270980834961
# to numeric:	 0.33170557022094727
# time manipulation:	 0.6830308437347412
# reordering:	 0.021635770797729492
# total formating time:	 1.0748579502105713
# records 624276
# time to upload 624,276 records: 37.952845096588135 or a rate of 16,450.0  records per second
# copy_from_stringio() done
# time to read files:	 1.4266822338104248
# time to make dataframe:	 0.22633147239685059
# total time to parse csvs 1.6531400680541992 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/jpl/Arroyo_Garage_01/
# rename columns:	 0.0003635883331298828
# mapping:	 0.03632950782775879
# to numeric:	 0.3191075325012207
# time manipulation:	 0.6568002700805664
# reordering:	 0.0297088623046875
# total formating time:	 1.0425715446472168
# records 603718
# time to upload 603,718 records: 41.64116191864014 or a rate of 14,500.0  records per second
# copy_from_stringio() done
# time to read files:	 1.1800358295440674
# time to make dataframe:	 0.22597765922546387
# total time to parse csvs 1.4061455726623535 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/jpl/Arroyo_Garage_01/
# rename columns:	 0.0003898143768310547
# mapping:	 0.04029536247253418
# to numeric:	 0.3328075408935547
# time manipulation:	 0.6861605644226074
# reordering:	 0.022573232650756836
# total formating time:	 1.0826797485351562
# records 620672
# time to upload 620,672 records: 40.58657693862915 or a rate of 15,290.0  records per second
# copy_from_stringio() done
# time to read files:	 1.4327940940856934
# time to make dataframe:	 0.22734284400939941
# total time to parse csvs 1.6602590084075928 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/jpl/Arroyo_Garage_01/
# rename columns:	 0.0003619194030761719
# mapping:	 0.0390927791595459
# to numeric:	 0.303802490234375
# time manipulation:	 0.7108821868896484
# reordering:	 0.025025606155395508
# total formating time:	 1.0794525146484375
# records 648980
# time to upload 648,980 records: 41.79664421081543 or a rate of 15,530.0  records per second
# copy_from_stringio() done
# time to read files:	 1.377847671508789
# time to make dataframe:	 0.22858142852783203
# total time to parse csvs 1.606581449508667 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/jpl/Arroyo_Garage_01/
# rename columns:	 0.0003991127014160156
# mapping:	 0.04230308532714844
# to numeric:	 0.3215162754058838
# time manipulation:	 0.7184827327728271
# reordering:	 0.025383472442626953
# total formating time:	 1.1083719730377197
# records 653846
# time to upload 653,846 records: 42.53428864479065 or a rate of 15,370.0  records per second
# copy_from_stringio() done
# time to read files:	 1.2918670177459717
# time to make dataframe:	 0.2199995517730713
# total time to parse csvs 1.5119903087615967 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/jpl/Arroyo_Garage_01/
# rename columns:	 0.0003578662872314453
# mapping:	 0.03825974464416504
# to numeric:	 0.29691410064697266
# time manipulation:	 0.6948890686035156
# reordering:	 0.031010866165161133
# total formating time:	 1.061689853668213
# records 631772
# time to upload 631,772 records: 39.85110688209534 or a rate of 15,850.0  records per second
# copy_from_stringio() done
# time to read files:	 0.14134645462036133
# time to make dataframe:	 0.029602766036987305
# total time to parse csvs 0.17102479934692383 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/jpl/Arroyo_Garage_01/
# rename columns:	 0.0003528594970703125
# mapping:	 0.015811681747436523
# to numeric:	 0.04352259635925293
# time manipulation:	 0.10478663444519043
# reordering:	 0.0036537647247314453
# total formating time:	 0.1683051586151123
# records 99737
# time to upload 99,737 records: 5.933932542800903 or a rate of 16,810.0  records per second
# copy_from_stringio() done
# running location id 7 from path /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/office_01/Parking_Lot_01/...
# num files 1,474
# time to read files:	 0.9886322021484375
# time to make dataframe:	 0.22397160530090332
# total time to parse csvs 1.2127602100372314 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/office_01/Parking_Lot_01/
# rename columns:	 0.00031876564025878906
# mapping:	 0.03242158889770508
# to numeric:	 0.46213793754577637
# time manipulation:	 0.48380589485168457
# reordering:	 0.02356100082397461
# total formating time:	 1.0025784969329834
# records 453236
# time to upload 453,236 records: 38.02462029457092 or a rate of 11,920.0  records per second
# copy_from_stringio() done
# time to read files:	 1.4263200759887695
# time to make dataframe:	 0.2581603527069092
# total time to parse csvs 1.6846339702606201 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/office_01/Parking_Lot_01/
# rename columns:	 0.0003724098205566406
# mapping:	 0.031679630279541016
# to numeric:	 0.5004942417144775
# time manipulation:	 0.5324490070343018
# reordering:	 0.026096820831298828
# total formating time:	 1.0913128852844238
# records 499457
# time to upload 499,457 records: 40.347657680511475 or a rate of 12,380.0  records per second
# copy_from_stringio() done
# time to read files:	 1.3735828399658203
# time to make dataframe:	 0.30582451820373535
# total time to parse csvs 1.6795895099639893 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/office_01/Parking_Lot_01/
# rename columns:	 0.0004551410675048828
# mapping:	 0.031135082244873047
# to numeric:	 0.6071350574493408
# time manipulation:	 0.5970315933227539
# reordering:	 0.031693458557128906
# total formating time:	 1.2676820755004883
# records 535576
# time to upload 535,576 records: 43.13687038421631 or a rate of 12,420.0  records per second
# copy_from_stringio() done
# time to read files:	 1.5970759391784668
# time to make dataframe:	 0.29007577896118164
# total time to parse csvs 1.887315034866333 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/office_01/Parking_Lot_01/
# rename columns:	 0.0003466606140136719
# mapping:	 0.03520774841308594
# to numeric:	 0.612067699432373
# time manipulation:	 0.572509765625
# reordering:	 0.028347253799438477
# total formating time:	 1.2487010955810547
# records 496576
# time to upload 496,576 records: 40.110350608825684 or a rate of 12,380.0  records per second
# copy_from_stringio() done
# time to read files:	 1.5529897212982178
# time to make dataframe:	 0.3144371509552002
# total time to parse csvs 1.8676300048828125 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/office_01/Parking_Lot_01/
# rename columns:	 0.0003681182861328125
# mapping:	 0.030182838439941406
# to numeric:	 0.6432840824127197
# time manipulation:	 0.5742452144622803
# reordering:	 0.028447389602661133
# total formating time:	 1.276754379272461
# records 527625
# time to upload 527,625 records: 44.19106149673462 or a rate of 11,940.0  records per second
# copy_from_stringio() done
# time to read files:	 1.9415369033813477
# time to make dataframe:	 0.3295755386352539
# total time to parse csvs 2.27130389213562 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/office_01/Parking_Lot_01/
# rename columns:	 0.0003502368927001953
# mapping:	 0.03288149833679199
# to numeric:	 0.6798741817474365
# time manipulation:	 0.6436705589294434
# reordering:	 0.030972003936767578
# total formating time:	 1.3879694938659668
# records 550770
# time to upload 550,770 records: 44.23037242889404 or a rate of 12,450.0  records per second
# copy_from_stringio() done
# time to read files:	 1.740067958831787
# time to make dataframe:	 0.34482312202453613
# total time to parse csvs 2.0850563049316406 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/office_01/Parking_Lot_01/
# rename columns:	 0.0003254413604736328
# mapping:	 0.036360979080200195
# to numeric:	 0.713573694229126
# time manipulation:	 0.6356005668640137
# reordering:	 0.03270435333251953
# total formating time:	 1.4188182353973389
# records 573049
# time to upload 573,049 records: 46.26769709587097 or a rate of 12,390.0  records per second
# copy_from_stringio() done
# time to read files:	 1.3716564178466797
# time to make dataframe:	 0.2633800506591797
# total time to parse csvs 1.635178565979004 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/office_01/Parking_Lot_01/
# rename columns:	 0.0003581047058105469
# mapping:	 0.02982163429260254
# to numeric:	 0.557124137878418
# time manipulation:	 0.5095319747924805
# reordering:	 0.02395486831665039
# total formating time:	 1.1210346221923828
# records 440744
# time to upload 440,744 records: 36.075576305389404 or a rate of 12,220.0  records per second
# copy_from_stringio() done
# time to read files:	 1.4051003456115723
# time to make dataframe:	 0.30618977546691895
# total time to parse csvs 1.7115449905395508 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/office_01/Parking_Lot_01/
# rename columns:	 0.0003285408020019531
# mapping:	 0.02878403663635254
# to numeric:	 0.6009464263916016
# time manipulation:	 0.5302791595458984
# reordering:	 0.027324914932250977
# total formating time:	 1.1878890991210938
# records 486237
# time to upload 486,237 records: 38.47302269935608 or a rate of 12,640.0  records per second
# copy_from_stringio() done
# time to read files:	 1.7312343120574951
# time to make dataframe:	 0.33816981315612793
# total time to parse csvs 2.0695910453796387 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/office_01/Parking_Lot_01/
# rename columns:	 0.0003886222839355469
# mapping:	 0.035129547119140625
# to numeric:	 0.7052547931671143
# time manipulation:	 0.6840105056762695
# reordering:	 0.03249025344848633
# total formating time:	 1.4575228691101074
# records 593441
# time to upload 593,441 records: 50.72409510612488 or a rate of 11,700.0  records per second
# copy_from_stringio() done
# time to read files:	 2.0396385192871094
# time to make dataframe:	 0.3551623821258545
# total time to parse csvs 2.394974708557129 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/office_01/Parking_Lot_01/
# rename columns:	 0.00034308433532714844
# mapping:	 0.03486943244934082
# to numeric:	 0.7131452560424805
# time manipulation:	 0.6607697010040283
# reordering:	 0.03046584129333496
# total formating time:	 1.439831018447876
# records 583102
# time to upload 583,102 records: 49.09595775604248 or a rate of 11,880.0  records per second
# copy_from_stringio() done
# time to read files:	 1.5940899848937988
# time to make dataframe:	 0.31785154342651367
# total time to parse csvs 1.9121263027191162 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/office_01/Parking_Lot_01/
# rename columns:	 0.0003867149353027344
# mapping:	 0.032614707946777344
# to numeric:	 0.6673576831817627
# time manipulation:	 0.5700855255126953
# reordering:	 0.028627395629882812
# total formating time:	 1.299286127090454
# records 545289
# time to upload 545,289 records: 44.96297645568848 or a rate of 12,130.0  records per second
# copy_from_stringio() done
# time to read files:	 1.6527400016784668
# time to make dataframe:	 0.32796502113342285
# total time to parse csvs 1.9808952808380127 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/office_01/Parking_Lot_01/
# rename columns:	 0.0003237724304199219
# mapping:	 0.031075239181518555
# to numeric:	 0.6216154098510742
# time manipulation:	 0.5577709674835205
# reordering:	 0.02607107162475586
# total formating time:	 1.2370688915252686
# records 496070
# time to upload 496,070 records: 39.25077533721924 or a rate of 12,640.0  records per second
# copy_from_stringio() done
# time to read files:	 1.4775142669677734
# time to make dataframe:	 0.29724860191345215
# total time to parse csvs 1.77496337890625 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/office_01/Parking_Lot_01/
# rename columns:	 0.0003368854522705078
# mapping:	 0.030460596084594727
# to numeric:	 0.6371598243713379
# time manipulation:	 0.5547566413879395
# reordering:	 0.026671409606933594
# total formating time:	 1.2496006488800049
# records 504464
# time to upload 504,464 records: 40.66157078742981 or a rate of 12,410.0  records per second
# copy_from_stringio() done
# time to read files:	 0.8019132614135742
# time to make dataframe:	 0.18264389038085938
# total time to parse csvs 0.9846854209899902 in /home/denny/Documents/mids/ev_charging/data/ACN-Data-Static-main/office_01/Parking_Lot_01/
# rename columns:	 0.00034356117248535156
# mapping:	 0.023653030395507812
# to numeric:	 0.3953845500946045
# time manipulation:	 0.3353109359741211
# reordering:	 0.016510963439941406
# total formating time:	 0.7714581489562988
# records 306711
# time to upload 306,711 records: 25.18108892440796 or a rate of 12,180.0  records per second
# copy_from_stringio() done
# total upload time: 35124.7581884861
# done with upload!

# %%
# df_unformated.head()

# %%
# copy_from_stringio(conn, df.iloc[:10,:], 'f_charges')

# %%
# # path = HOME_PATH+'/data/ACN-Data-Static-main/office_01/Parking_Lot_01/'
# path = HOME_PATH + '/data/ACN-Data-Static-main' + ldf.loc[6,'path']
# location_id = ldf.loc[6,'id']
# print(location_id, path)
# start_time = time.time()
# 
# import concurrent.futures
# import urllib.request
# with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
#         
#     for indx_loc in ldf.index:
#         os.chdir(HOME_PATH)
#         # if indx_loc == 0:
#         path = HOME_PATH + '/data/ACN-Data-Static-main' + ldf.loc[indx_loc,'path']
#         location_id = ldf.loc[indx_loc,'id']
#         print(f'running location id {location_id} from path {path}...')
#         filenames = get_csvs(path)
#         # 
#         print(f'num files {len(filenames):,}')
#         chunksize = 1000
#         for chunk in range(0,100,100):#len(filenames),chunksize):
#             # print(chunk, len(filenames[chunk:chunk+chunksize]))
#             df_unformated = filename_csvs_to_df(path, filenames[chunk:chunk+chunksize])
#             df = format_charges(df_unformated)
#             # copy_from_stringio(conn, df, 'f_charges')
#             break
#         break
#         # df_unformated = dir_csvs_to_df(path)
#         # df = format_charges(df_unformated)
#         # copy_from_stringio(conn, df, 'f_charges')
#         
#     print(f'total upload time: {time.time() - start_time}')
#     print('done with upload!')

# %%
# copy_from_stringio(conn, df.iloc[0:200,:], 'f_charges')

# %%
# df_unformated.shape

# %%
# pd.to_datetime([datetime.datetime.now(), datetime.datetime.now()], format='%Y-%m-%d %H:%M:%S')
# df.iloc[0:1,0]

# %%
# import time
# start_time = time.time()
# new_time = start_time
# 
# # rename columns to match db
# df.rename(columns={"":"datetime",'Charging Current (A)':'charging_current_amps', 'Actual Pilot (A)':'actual_pilot_amps', 'Voltage (V)':'voltage_volts',
#        'Charging State':'charging_state', 'Energy Delivered (kWh)':'energy_delivered_kwh', 'Power (kW)':'power_kw','filename':'file_id'}, inplace=True)
# print(f'rename columns:\t {time.time()-new_time}')
# new_time = time.time()
# 
# # map location and files to foreign key ids
# # https://stackoverflow.com/a/46049755/6432367
# df['location_id'] = location_id
# 
# df['file_id'] = df['file_id'].map(fdf.set_index('filename')['id'])
# print(f'mapping:\t {time.time()-new_time}')
# new_time = time.time()
# 
# # add nans to empty numeric fields
# # df[['charging_current_amps','actual_pilot_amps','voltage_volts','energy_delivered_kwh','power_kw']] = df[['charging_current_amps','actual_pilot_amps','voltage_volts','energy_delivered_kwh','power_kw']].apply(pd.to_numeric, errors='coerce', axis=1)
# for col in ['charging_current_amps','actual_pilot_amps','voltage_volts','energy_delivered_kwh','power_kw']:
#     df[col] = pd.to_numeric(df[col], errors='coerce')
# 
# print(f'to numeric:\t {time.time()-new_time}')
# new_time = time.time()
# 
# # apply date transformations
# df['datetime'] = pd.to_datetime(df['datetime'], format='')
# pd.to_timestamp
# df['date'] = df['datetime'].dt.date
# df['time'] = df['datetime'].dt.time
# 
# print(f'time manipulation:\t {time.time()-new_time}')
# new_time = time.time()
# 
# # put columns in order
# df = df[['datetime', 'location_id', 'file_id', 'charging_current_amps', 'actual_pilot_amps', 'voltage_volts', 'charging_state', 'energy_delivered_kwh', 'power_kw', 'date', 'time']]
# print(f'reordering:\t {time.time()-new_time}')
# new_time = time.time()
# print(time.time()-start_time)

# %%
# start_time = time.time()
# new_time = start_time
# for col in ['charging_current_amps','actual_pilot_amps','voltage_volts','energy_delivered_kwh','power_kw']:
#     df[col] = pd.to_numeric(df[col], errors='coerce')
#     print(col, time.time()- new_time )
#     new_time = time.time()
# print(f'total time {time.time() - start_time}')

# %%
# copy_from_stringio(conn, df.iloc[0:20000,:], 'f_charges')
# copy_from_stringio(conn, df, 'f_charges')
