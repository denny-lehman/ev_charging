# %%
# Adapted from Watttime docs
# https://docs.watttime.org/#tag/Authentication/operation/post_username_register_post

# %%
! pip install watttime

# %%
import requests

# %%
# To register, use the code below. Please note that for these code examples we are using filler values for username
# (freddo), password (the_frog), email (freddo@frog.org), org (freds world) and you should replace each if you are
# copying and pasting this code.

import requests
register_url = 'https://api.watttime.org/register'
params = {'username': 'cbtest',
         'password': 'Chargebuddy24!',
         'email': 'den@ischool.berkeley.edu',
         'org': 'Berkeley'}
rsp = requests.post(register_url, json=params)
print(rsp.text)
# Out:
# {"user":"cbtest","ok":"User created"}

# %%
# To login and obtain an access token, use this code:

import requests
from requests.auth import HTTPBasicAuth
login_url = 'https://api.watttime.org/login'
rsp = requests.get(login_url, auth=HTTPBasicAuth('cbtest', 'Chargebuddy24!'))
TOKEN = rsp.json()['token']
print(rsp.json())
# Out:
# {'token': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.eyJzY29wZSI6ImJhc2ljIiwiaWF0IjoxNzExMDg5NDk3LCJleHAiOjE3MTEwOTEyOTcsImlzcyI6IldhdHRUaW1lIiwic3ViIjoiY2J0ZXN0In0.OAIRtzV6qZOeqC5WjhUXekD4wR1GxLjnwTr8aOeg1QWON6l2-Tml-43RAO9i0ijms13SKIb_UVOIqrn3bFpkIOBWfRG2nEGuT9qsypEHMt4MFH8NSgqQSSKx6oWCVdxRLtAkuWA06oqHqAnDRMN1DDt6DSp5uqQEgDTxKYNRw0wZSsTvcBbyvdA1KNL6jWeontTFu3zEWapyFVeXQQMpZzvqXjPmKOl0uhKxaCmmuSySwFucoIacUqthMLDykoiZ3O7W7oyrZLWnf5PkyTo_xqBiF20rhmkme1Va7WalW5gxFq3DtdrFlr-2r6HRIjTwenWvtj9d5L3gizNtWkcKDg'}

# %%
import requests

url = "https://api.watttime.org/v3/my-access"

# Provide your TOKEN here, see https://docs.watttime.org/#tag/Authentication/operation/get_token_login_get for more information
TOKEN = "eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.eyJzY29wZSI6ImJhc2ljIiwiaWF0IjoxNzExMDg5NDk3LCJleHAiOjE3MTEwOTEyOTcsImlzcyI6IldhdHRUaW1lIiwic3ViIjoiY2J0ZXN0In0.OAIRtzV6qZOeqC5WjhUXekD4wR1GxLjnwTr8aOeg1QWON6l2-Tml-43RAO9i0ijms13SKIb_UVOIqrn3bFpkIOBWfRG2nEGuT9qsypEHMt4MFH8NSgqQSSKx6oWCVdxRLtAkuWA06oqHqAnDRMN1DDt6DSp5uqQEgDTxKYNRw0wZSsTvcBbyvdA1KNL6jWeontTFu3zEWapyFVeXQQMpZzvqXjPmKOl0uhKxaCmmuSySwFucoIacUqthMLDykoiZ3O7W7oyrZLWnf5PkyTo_xqBiF20rhmkme1Va7WalW5gxFq3DtdrFlr-2r6HRIjTwenWvtj9d5L3gizNtWkcKDg"
headers = {"Authorization": f"Bearer {TOKEN}"}
params = {}
response = requests.get(url, headers=headers, params=params)
response.raise_for_status()
print(response.json())
# Out:
# {'signal_types': [{'signal_type': 'co2_moer', 'regions': [{'region': 'CAISO_NORTH', 'region_full_name': 'California ISO Northern', 'parent': 'CAISO', 'data_point_period_seconds': 300, 'endpoints': [{'endpoint': 'v3/historical', 'models': [{'model': '2022-10-01', 'data_start': '2020-01-01', 'train_start': '2020-03-01', 'train_end': '2022-03-01', 'type': 'binned_regression'}, {'model': '2023-03-01', 'data_start': '2020-03-01', 'train_start': '2021-01-01', 'train_end': '2023-03-01', 'type': 'binned_regression'}]}, {'endpoint': 'v3/forecast', 'models': [{'model': '2022-10-01', 'data_start': '2021-12-31', 'train_start': '2020-01-01', 'train_end': '2021-12-31'}, {'model': '2023-03-01', 'data_start': '2023-01-01', 'train_start': '2021-01-01', 'train_end': '2023-01-01'}]}]}]}, {'signal_type': 'health_damage', 'regions': [{'region': 'CAISO_NORTH', 'region_full_name': 'California ISO Northern', 'parent': 'CAISO', 'data_point_period_seconds': 300, 'endpoints': [{'endpoint': 'v3/historical', 'mo
# ...

# %%
import pprint
pp = pprint.PrettyPrinter()
pp.pprint(response.json())
# Out:
# {'signal_types': [{'regions': [{'data_point_period_seconds': 300,
#                                 'endpoints': [{'endpoint': 'v3/historical',
#                                                'models': [{'data_start': '2020-01-01',
#                                                            'model': '2022-10-01',
#                                                            'train_end': '2022-03-01',
#                                                            'train_start': '2020-03-01',
#                                                            'type': 'binned_regression'},
#                                                           {'data_start': '2020-03-01',
#                                                            'model': '2023-03-01',
#                                                            'train_end': '2023-03-01',
#                                                            'train_start': '2021-01-01',
# ...

# %%
import requests

url = "https://api.watttime.org/v3/forecast"

# Provide your TOKEN here, see https://docs.watttime.org/#tag/Authentication/operation/get_token_login_get for more information
TOKEN = "eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.eyJzY29wZSI6ImJhc2ljIiwiaWF0IjoxNzExMDg5NDk3LCJleHAiOjE3MTEwOTEyOTcsImlzcyI6IldhdHRUaW1lIiwic3ViIjoiY2J0ZXN0In0.OAIRtzV6qZOeqC5WjhUXekD4wR1GxLjnwTr8aOeg1QWON6l2-Tml-43RAO9i0ijms13SKIb_UVOIqrn3bFpkIOBWfRG2nEGuT9qsypEHMt4MFH8NSgqQSSKx6oWCVdxRLtAkuWA06oqHqAnDRMN1DDt6DSp5uqQEgDTxKYNRw0wZSsTvcBbyvdA1KNL6jWeontTFu3zEWapyFVeXQQMpZzvqXjPmKOl0uhKxaCmmuSySwFucoIacUqthMLDykoiZ3O7W7oyrZLWnf5PkyTo_xqBiF20rhmkme1Va7WalW5gxFq3DtdrFlr-2r6HRIjTwenWvtj9d5L3gizNtWkcKDg"
headers = {"Authorization": f"Bearer {TOKEN}"}
params = {
    "region": "CAISO_NORTH",
    "signal_type": "co2_moer",
}
response = requests.get(url, headers=headers, params=params)
response.raise_for_status()
print(response.json())
# Out:
# {'data': [{'point_time': '2024-03-22T06:45:00+00:00', 'value': 961.1}, {'point_time': '2024-03-22T06:50:00+00:00', 'value': 961.1}, {'point_time': '2024-03-22T06:55:00+00:00', 'value': 959.5}, {'point_time': '2024-03-22T07:00:00+00:00', 'value': 959.8}, {'point_time': '2024-03-22T07:05:00+00:00', 'value': 957.8}, {'point_time': '2024-03-22T07:10:00+00:00', 'value': 958.2}, {'point_time': '2024-03-22T07:15:00+00:00', 'value': 956.5}, {'point_time': '2024-03-22T07:20:00+00:00', 'value': 956.8}, {'point_time': '2024-03-22T07:25:00+00:00', 'value': 957.5}, {'point_time': '2024-03-22T07:30:00+00:00', 'value': 957.7}, {'point_time': '2024-03-22T07:35:00+00:00', 'value': 956.2}, {'point_time': '2024-03-22T07:40:00+00:00', 'value': 954.4}, {'point_time': '2024-03-22T07:45:00+00:00', 'value': 955.5}, {'point_time': '2024-03-22T07:50:00+00:00', 'value': 954.5}, {'point_time': '2024-03-22T07:55:00+00:00', 'value': 953.3}, {'point_time': '2024-03-22T08:00:00+00:00', 'value': 951.1}, {'point_time
# ...

# %%
print('printing forecast values from CAISO: ', params.items())
pp.pprint(response.json())
# Out:
# printing forecast values from CAISO:  dict_items([('region', 'CAISO_NORTH'), ('signal_type', 'co2_moer')])
# {'data': [{'point_time': '2024-03-22T06:45:00+00:00', 'value': 961.1},
#           {'point_time': '2024-03-22T06:50:00+00:00', 'value': 961.1},
#           {'point_time': '2024-03-22T06:55:00+00:00', 'value': 959.5},
#           {'point_time': '2024-03-22T07:00:00+00:00', 'value': 959.8},
#           {'point_time': '2024-03-22T07:05:00+00:00', 'value': 957.8},
#           {'point_time': '2024-03-22T07:10:00+00:00', 'value': 958.2},
#           {'point_time': '2024-03-22T07:15:00+00:00', 'value': 956.5},
#           {'point_time': '2024-03-22T07:20:00+00:00', 'value': 956.8},
#           {'point_time': '2024-03-22T07:25:00+00:00', 'value': 957.5},
#           {'point_time': '2024-03-22T07:30:00+00:00', 'value': 957.7},
#           {'point_time': '2024-03-22T07:35:00+00:00', 'value': 956.2},
#           {'point_time': '2024-03-22T07:40:00+00:00', 'value': 954.4},
# ...
